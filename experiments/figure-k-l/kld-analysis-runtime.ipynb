# %%
import pandas as pd
import numpy as np
import seaborn as sns
from matplotlib import pyplot as plt
import statistics
plt.rc('figure', facecolor='w', figsize=[4,3])

# %%
df = pd.read_csv('k_perf.csv')
print(df)
ax = df.plot(x="K-min-mer length", y="Runtime (s)", legend=False)
ax2 = ax.twinx()
df.plot(x="K-min-mer length", y="Memory (GB)", ax=ax2, legend=False, color="r")
ax.set(ylim=(5, 35))
ax2.set(ylim=(7, 13))
ax.set_ylabel('Runtime (s)')
ax2.set_ylabel('Memory (GB)')
ax.figure.legend(bbox_to_anchor=(0.5, 0.3), loc='upper left', borderaxespad=0)
ax.tick_params(axis='x', rotation=45)
fig = sns_plot.get_figure()
plt.show()

fig.savefig("k_analysis_runtime.pdf", bbox_inches='tight', dpi =300)
# Out:
#     K-min-mer length  Runtime (s)  Memory (GB)
# 0                  2        23.77        12.23
# 1                  3        25.37        12.29
# 2                  4        22.28        12.30
# 3                  5        19.98        12.31
# 4                  6        18.64        12.27
# 5                  7        17.19        12.27
# 6                  8        15.98        12.28
# 7                  9        15.18        12.28
# 8                 10        15.17        12.28
# 9                 11        14.63        12.28
# 10                12        14.46        12.27

# %%
df = pd.read_csv('l_perf.csv')
print(df)
ax = df.plot(x="Minimizer length", y="Runtime (s)", legend=False)
ax2 = ax.twinx()
df.plot(x="Minimizer length", y="Memory (GB)", ax=ax2, legend=False, color="r")
ax.set(ylim=(5, 35))
ax2.set(ylim=(7, 13))
ax.set_ylabel('Runtime (s)')
ax2.set_ylabel('Memory (GB)')
ax.figure.legend(bbox_to_anchor=(0.5, 0.3), loc='upper left', borderaxespad=0)
ax.tick_params(axis='x', rotation=45)
fig = sns_plot.get_figure()
plt.show()

fig.savefig("l_analysis_runtime.pdf", bbox_inches='tight', dpi =300)
# Out:
#     Minimizer length  Runtime (s)  Memory (GB)
# 0                 10        19.42        12.29
# 1                 11        19.98        12.31
# 2                 12        19.93        12.28
# 3                 13        19.70        12.28
# 4                 14        20.11        12.31
# 5                 15        19.65        12.29
# 6                 16        19.80        12.28
# 7                 17        20.05        12.29
# 8                 18        20.06        12.30
# 9                 19        20.14        12.30
# 10                20        20.04        12.31
# 11                21        19.95        12.30
# 12                22        19.90        12.27
# 13                23        20.00        12.28
# 14                24        19.95        12.27
# 15                25        19.86        12.28
# 16                26        19.97        12.29
# 17                27        19.92        12.29
# 18                28        19.97        12.29
# ...

# %%
df = pd.read_csv('d_perf.csv')
print(df)
ax = df.plot(x="Minimizer density", y="Runtime (s)", legend=False)
ax2 = ax.twinx()
df.plot(x="Minimizer density", y="Memory (GB)", ax=ax2, legend=False, color="r")
ax.set(ylim=(5, 35))
ax2.set(ylim=(7, 13))
ax.set_ylabel('Runtime (s)')
ax2.set_ylabel('Memory (GB)')
ax.figure.legend(bbox_to_anchor=(0.5, 0.3), loc='upper left', borderaxespad=0)
ax.tick_params(axis='x', rotation=45)
fig = sns_plot.get_figure()
plt.show()
fig.savefig("d_analysis_runtime.pdf", bbox_inches='tight', dpi =300)
# Out:
#     Minimizer density  Runtime (s)  Memory (GB)
# 0               0.005        13.11        12.05
# 1               0.006        14.45        12.16
# 2               0.007        15.83        12.17
# 3               0.008        17.31        12.24
# 4               0.009        18.63        12.26
# 5               0.010        19.87        12.30
# 6               0.011        21.61        12.34
# 7               0.012        22.97        12.35
# 8               0.013        24.95        12.40
# 9               0.014        26.25        12.43
# 10              0.015        27.47        12.49
# 11              0.016        28.94        12.51
# 12              0.017        29.89        12.56
# 13              0.018        31.03        12.61
# 14              0.019        32.38        12.63
# 15              0.020        33.77        12.66
